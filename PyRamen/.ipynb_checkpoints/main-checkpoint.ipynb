# %%
# -*- coding: UTF-8 -*-
"""PyRamen Homework Starter."""

# @TODO: Import libraries
import csv
from pathlib import Path

# @TODO: Set file paths for menu_data.csv and sales_data.csv
menu_filepath = Path('../../PyRamen/menu_data.csv')
sales_filepath = Path('../../PyRamen/menu_data.csv')

# @TODO: Initialize list objects to hold our menu and sales data
menu = []
sales = []

# @TODO: Read in the menu data into the menu list
with open (menu_filepath, 'r') as menufile:

    # Pass in the csvfile to the csv.reader() function
    # (with ',' as the delmiter/separator) and return the csvreader object
    csv_menu_reader= csv.reader(menufile, delimiter= ',')

    # Read the header row first
    csv_menu_header= next(csv_menu_reader)

# Loop over every row in csv_menu_reader and append to menu list
for item, category, price, cost in csv_menu_reader:
    menu.append(csv_menu_reader)

print (menu)

# @TODO: Read in the sales data into the sales list
with open (sales_filepath, 'r') as salesfile:

    # Pass in the csvfile to the csv.reader() function
    # (with ',' as the delmiter/separator) and return the csvreader object
    csv_sales_reader= csv.reader(salesfile, delimiter= ',')
    
    # Read the header row first
    csv_sales_header= next(csv_sales_reader)

# Loop over every row in csv_sales_Reader and append to sales list
for line_item_id, date, credit_card, quantity, menu_item in csv_sales_reader:
    sales.append(csv_sales_reader)
    
print (sales)

# @TODO: Initialize dict object to hold our key-value pairs of items and metrics
report = {}

# Initialize a row counter variable
row_count = 0

# @TODO: Loop over every row in the sales list object
for quantity,menu_item in sales:

    # Line_Item_ID,Date,Credit_Card_Number,Quantity,Menu_Item
    # @TODO: Initialize sales data variables
    
    quantity= int(sales[Quantity])
    menu_item= int(sales[Menu_item])
    
    # @TODO
    # If the item value not in the report, add it as a new entry with initialized metrics
    # Naming convention allows the keys to be ordered in logical fashion, count, revenue, cost, profit
    for sales_item, value in report.items():
        
        # Check if sales_item is present in the report
        if sales_item is in report.items():
            print ({report})
            
        elif sales_item, value is not in report.items():
            sales_item= menu_item
            value= 
            {"01-count": 0,
            "02-revenue": 0,
            "03-cogs": 0,
            "04-profit": 0,
            }


    # @TODO: For every row in our sales data, loop over the menu records to determine a match
     for item, price, cost in menu:

        # Item,Category,Description,Price,Cost
        # @TODO: Initialize menu data variables
        item= menu[item]
        price= int(menu[price])
        cost= int(menu[cost])

        # @TODO: Calculate profit of each item in the menu data
        profit= price- cost

        # @TODO: If the item value in our sales data is equal to the any of the items in the menu, then begin tracking metrics for that item
        if report[sales_item] == item:
            ### What am I missing here?
                        
            # @TODO: Print out matching menu data
            print (f"The Key {report[sales_item]} in report dictionary matches with that of {item} in Menu list")

            # @TODO: Cumulatively add up the metrics for each item key
            report[value]["01-count"]+= quantity
            report[value]["02-revenue"]+= price* quantity
            report[value]["03-cogs"]+= cost* quantity
            report[value]["04-profit"]+= profit* quantity


        # @TODO: Else, the sales item does not equal any of the item in the menu data, therefore no match
         else:
            print (f"{report[sales_item]} does not equal {item}! NO MATCH")


    # @TODO: Increment the row counter by 1
    row_counter += 1
    ### Where and how to call the row_counter variable?

# @TODO: Print total number of records in sales data
print (f"{report[sales_item]} {report[value]}")



# @TODO: Write out report to a text file (won't appear on the command line output)
report_text= open('report.txt','w')

with open (report_text, 'w') as textfile:

print (textfile)
